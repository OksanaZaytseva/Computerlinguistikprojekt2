# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#!pip install fake_useragent
from fake_useragent import UserAgent
print(UserAgent().chrome)
# Out:
# Mozilla/5.0 (Linux; Android 11; moto e20 Build/RONS31.267-94-14) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.6261.64 Mobile Safari/537.36

# %% [markdown]
# # Отряд самоубийц

# %% [markdown]
# ## Bad reviews (264) (выгружены)

# %%
page_link = 'https://www.kinopoisk.ru/film/468522/reviews/'
response = requests.get(page_link, headers={'User-Agent': UserAgent().chrome})

# %%
url = 'https://www.kinopoisk.ru/film/468522/reviews/' 
r = requests.get(url) # загружаем страницу по ссылке
print(r.status_code)

# %%
soup = BeautifulSoup(r.text, features="html.parser")
print(soup.prettify())

# %%
kinopoisk_url_list_bad = []


for page_b in range(1, 28):
    url_page_bad = f'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/{page_b}/'
    kinopoisk_url_list_bad.append(url_page_bad)
print(kinopoisk_url_list_bad)
# Out:
# ['https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/9/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/10/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/11/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/12/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/13/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/14/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/15/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/16/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/17/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/18/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/19/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/20/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/21/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/22/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/23/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/24/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/25/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/26/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/bad/perpage/10/page/27/']

# %%
#url_bad = kinopoisk_url_list_bad[26]
#url_bad

# %%
url_bad = kinopoisk_url_list_bad[26]

def review_bad_parsing(url_bad):
    page_bad = requests.get(url_bad)
    soup_bad = BeautifulSoup(page_bad.text, features = 'html.parser')
    review_content_bad = soup_bad.find_all('tbody')
    review_bad = [bad.text for bad in review_content_bad]
    final_review_bad = ' '.join(review_bad)
    return final_review_bad
#print(review_bad_parsing(url_bad))

# %%
from time import sleep

all_reviews_bad = [] # список с отрицательными отзывами

for b in kinopoisk_url_list_bad:
    try:
        rev_bad = review_bad_parsing(b)
        all_reviews_bad.append(rev_bad)
        sleep(5)
    except:
        print(b) #try, except показывает, какая ссылка ломает парсер

# %%
#all_reviews_bad

# %%
df_bad = pd.DataFrame(all_reviews_bad)

# %%
df_bad
# Out:
#                                                     0
# 0   \n\n\n\nСупергеройское кино - по моему глубоча...
# 1   \n\n\n\nНадысь от скуки цвета смарагда решился...
# 2   \n\n\n\nИ снова Расширенная Вселенная DC тороп...
# 3   \n\n\n\nЖдала, хотела скорее увидеть, побежала...
# 4   \n\n\n\nВ общем, на днях мне удалось посмотрет...
# 5   \n\n\n\nНачиная с начала, как вообще выглядит ...
# 6   \n\n\n\nЧестно говоря, не ждала этого фильма, ...
# 7   \n\n\n\nНе могу сейчас вспомнить другой фильм,...
# 8   \n\n\n\nБожемой, а я еще смела придираться к '...
# 9   \n\n\n\nКогда в свет выходит очередной долгожд...
# 10  \n\n\n\nНи одна из замечательных песен, что ис...
# 11  \n\n\n\n«Отряд самоубийц» настолько убог, что ...
# 12  \n\n\n\nЯ всегда подхожу к оценкам кинофильмов...
# 13  \n\n\n\nМногообещающий блокбастер с популярным...
# 14  \n\n\n\nПризнаюсь честно, фильм очень ждал, но...
# 15  \n\n\n\nПосле прочтения ряда восторженных отзы...
# 16  \n\n\n\nА я говорил что фильм будет плохим, го...
# 17  \n\n\n\nНа «Отряд самоубийц», в отличие от «Ст...
# 18  \n\n\n\nВпервые про этот фильм стали говорить ...
# 19  \n\n\n\nТрейлеры «Отряда самоубийц» не хило та...
# 20  \n\n\n\nА начиналось всё многообещающе. Яркие ...
# 21  \n\n\n\nПомните фразу 'бессмысленный и беспоща...
# 22  \n\n\n\nЕсть такая притча о добром самаритянин...
# 23  \n\n\n\nЯ очень хотел увидеть этот фильм и оче...
# 24  \n\n\n\nЧто же, мы дожили до таких дней, когда...
# 25  \n\n\n\nDC умирает. Начиная от пиар компании, ...
# 26  \n\n\n\nБуквально пару дней назад я сходил на ...

# %%
df_bad.to_csv('Parsing_Squad_bad_fin.txt', sep='\t', index=False)

# %% [markdown]
# ## Good reviews (272) (выгружены)

# %%
kinopoisk_url_list_good = []


for page_g in range(1, 29):
    url_page_good = f'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/{page_g}/'
    kinopoisk_url_list_good.append(url_page_good)
print(kinopoisk_url_list_good)
# Out:
# ['https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/9/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/10/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/11/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/12/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/13/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/14/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/15/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/16/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/17/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/18/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/19/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/20/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/21/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/22/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/23/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/24/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/25/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/26/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/27/', 'https://www.kinopoisk.ru/film/468522/reviews/ord/date/status/good/perpage/10/page/28/']

# %%
url_good = kinopoisk_url_list_good[0]

def review_good_parsing(url_good):
    page_good = requests.get(url_good)
    soup_good = BeautifulSoup(page_good.text, features = 'html.parser')
    review_content_good = soup_good.find_all('tbody')
    review_good = [good.text for good in review_content_good]
    final_review_good = ' '.join(review_good)
    return final_review_good
print(review_good_parsing(url_good))
# Out:
# Такое кино не могло не появиться в десятые - время расцвета жанра. Тем более, подходящие персонажи у DC были давно. Итак, сегодня в программе - суперзлодеи, которым пришлось стать супергероями в рамках госпрограммы, инициированной крупной чиновницей Амандой Уоллер (рядовой зритель может помнить ее по 'Зеленому Фонарю'). Первое задание появляется сразу же - жуткая и могущественная Чародейка на пару со своим братом пытаются захватить мир...
#
# Интересная задумка, верно? И исполнена бодро - крутые драки, харизматичные герои и так далее. Причем героев даже постарались раскрыть - почти о каждом можно что-то сказать. Исключениями остаются Катана, Убийца Крок и, пожалуй, командир Отряда Рик Флэгг, который не злодей, а просто приставленный сверху начальник. Да и остальные... Да, об остальных рассказывают, но как-то поверхностно. Харли Квинн ненормальная и влюблена в Джокера, а еще она бывший психиатр - но на последнее в ее характере указывает всего одна реплика. Дэдшот - хороший, в принципе, мужик, крепкий брутальный шутник (а каким еще ему быть, если его играет Уилл Смит?), привязан к маленькой дочери - но и все. Дьябло религиозен и страдает от совершенных грехов. Капитан Бумеранг - просто забавный отморозок и единственный в команде, кто действительно похож на злодея. Серьезно, все остальные плохими ребятами не выглядят. Возможно, на каком-то этапе создания фильма они таковыми и были, но перемонтаж после зрительского недовольства слишком мрачным 'Бэтменом против Супермена' отправил всю эту мрачность в канализацию. В итоге далеко не всегда получается верить трагическим предысториям героев.
#
# Проблемой стал и Джокер. Понятно, что лет через сколько-то это уже не будет восприниматься так остро, но когда появление какого-то персонажа обещают и обставляют как великое событие, а в самом кино он появляется минут на пять, это выглядит несколько странно. А ведь версия вышла явно интересная - может, и не уровня Хита Леджера из 'Темного Рыцаря', но харизматичный Джаред Лето не дал бы нам заскучать.
#
#                             просмотра вами.

# %%
from time import sleep 

all_reviews_good = [] # список с положительными отзывами

for g in kinopoisk_url_list_good:
    try:
        rev_good = review_good_parsing(g)
        all_reviews_good.append(rev_good)
        sleep (5)
    except:
        print(g) #try, except показывает, какая ссылка ломает парсер

# %%
all_reviews_good

# %%
df_good = pd.DataFrame(all_reviews_good)
df_good
# Out:
#                                                     0
# 0   \n\n\n\nТакое кино не могло не появиться в дес...
# 1   \n\n\n\nОтряд самоубийц. Максимально распиарен...
# 2   \n\n\n\nСлежу за экранизациями комиксов DC, та...
# 3   \n\n\n\nС той поры, как с небес на землю снизо...
# 4   \n\n\n\nНа фильм сходила в кино достаточно дав...
# 5   \n\n\n\nYou're loving on the psychopath sittin...
# 6   \n\n\n\n«Отряд самоубийц» - фантастический бое...
# 7   \n\n\n\nДиванные критики решили не уступать пр...
# 8   \n\n\n\nСразу к делу.\n\r\nНе самый плохой сюж...
# 9   \n\n\n\nОтряд самоубийц. Фильм, который еще с ...
# 10  \n\n\n\nНет, серьёзно, сколько можно? Проблема...
# 11  \n\n\n\nБез спойлеров. Мое мнение - видно, что...
# 12  \n\n\n\nОтряд самоубийц - типичное супергеройс...
# 13  \n\n\n\nЗаголовок статьи, является ответом на ...
# 14  \n\n\n\nПро эскадрон\n\r\nФабулой фильма (и со...
# 15  \n\n\n\nДля меня, как для человека, который не...
# 16  \n\n\n\nОжидаемый комикс.\n\nШикарный каст - М...
# 17  \n\n\n\n++ Харли Квинн. Она великолепна. Она и...
# 18  \n\n\n\nВокруг этого фильма была очень, очень ...
# 19  \n\n\n\n«Лучше умереть стоя, чем жить на колен...
# 20  \n\n\n\nФильм 'Отряд Самоубийц' - пожалуй, сам...
# 21  \n\n\n\nВ российский кинопрокат вышел фильм 'О...
# 22  \n\n\n\nСамый ожидаемый фильм августа я посети...
# 23  \n\n\n\nС одной стороны, могу честно сказать, ...
# 24  \n\n\n\nТрейлеры и реклама этого фильма задали...
# 25  \n\n\n\nСегодня я наконец-то сходил на 'Отряд ...
# 26  \n\n\n\nОтличная реклама, неплохой режиссер, н...
# 27  \n\n\n\nДа. Да. Да. Да. Идите на этот фильм, ш...

# %%
df_good.to_csv('Parsing_Squad_good_fin.txt', sep='\t', index=False)

# %% [markdown]
# # Повелитель стихий

# %% [markdown]
# ## Bad reviews (329) (выгружены)

# %%
page_link1 = 'https://www.kinopoisk.ru/film/417855/reviews/'
response1 = requests.get(page_link1, headers={'User-Agent': UserAgent().chrome})

url1 = 'https://www.kinopoisk.ru/film/417855/reviews/' 
r1 = requests.get(url1) # загружаем страницу по ссылке
print(r1.status_code)

if r1.status_code == 200:
    soup1 = BeautifulSoup(r1.text, features="html.parser")
    #print(soup1.prettify())
else:
    print("ERROR")
# Out:
# 200

# %%
kinopoisk_url_list_bad_air = []


for page_b1 in range(1, 34):
    url_page_bad1 = f'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/bad/perpage/10/page/{page_b1}/'
    kinopoisk_url_list_bad_air.append(url_page_bad1)
#print(kinopoisk_url_list_bad_air)

# %%
url_bad1 = kinopoisk_url_list_bad_air[12]

def review_bad_parsing_air(url_bad1):
    page_bad1 = requests.get(url_bad1)
    soup_bad1 = BeautifulSoup(page_bad1.text, features = 'html.parser')
    review_content_bad1 = soup_bad1.find_all('tbody')
    review_bad1 = [bad1.text for bad1 in review_content_bad1]
    final_review_bad1 = ' '.join(review_bad1)
    return final_review_bad1
#print(review_bad_parsing_air(url_bad1))

# %%
from time import sleep

all_reviews_bad_air = [] # список с отрицательными отзывами

for b1 in kinopoisk_url_list_bad_air:
    try:
        rev_bad1 = review_bad_parsing_air(b1)
        all_reviews_bad_air.append(rev_bad1)
        sleep(5)
    except:
        print(b1) #try, except показывает, какая ссылка ломает парсер

# %%
#all_reviews_bad_air

# %%
df_bad_air = pd.DataFrame(all_reviews_bad_air)
df_bad_air
# Out:
#                                                     0
# 0   \n\n\n\nПо-настоящему добрый и качественный, н...
# 1   \n\n\n\nФильм «Повелитель стихий» — это экрани...
# 2   \n\n\n\nБыла слегка удивлена, когда оказалась ...
# 3   \n\n\n\n'Аватар: Легенда об Аанге' - это культ...
# 4   \n\n\n\n«У каждого свое предназначение. Важно ...
# 5   \n\n\n\nДумаю это не первый случай когда кому-...
# 6   \n\n\n\nЖелание посмотреть этот фильм во мне з...
# 7   \n\n\n\nЭта экранизация весьма интересного и к...
# 8   \n\n\n\nУзнав, что по образу и подобию аниме '...
# 9   \n\n\n\nПервое. События и факты в фильме вылет...
# 10  \n\n\n\nДавно ждал этот фильм, ещё с тех пор, ...
# 11  \n\n\n\nКогда я посмотрела трейлер к фильму 'П...
# 12  \n\n\n\nВкусы у всех разные, но я, как человек...
# 13  \n\n\n\n«Ужас, какой ужас.» \n\r\nПервое впеча...
# 14  \n\n\n\nХорошая реклама и популярность мультфи...
# 15  \n\n\n\nВ жизни не много вещей, от которых я, ...
# 16  \n\n\n\nКиноверсия известного мультсериала 'Ав...
# 17  \n\n\n\nИногда ты посмотрел фильм и не можешь ...
# 18  \n\n\n\nВ прошлом году случайно увидел серию '...
# 19  \n\n\n\nНачну с того, что я смотрела весь муль...
# 20  \n\n\n\nПожалуй это худшая экранизация Мультфи...
# 21  \n\n\n\nПолгода назад мне мой друг позвонил на...
# 22  \n\n\n\nЗа неделю прекрасного путешествия мне ...
# 23  \n\n\n\nФильм Повелитель стихий я ждал потому ...
# 24  \n\n\n\nВау… Классно! Первые увиденные мной ка...
# 25  \n\n\n\nЕще в трейлере мне не понравился этот ...
# 26  \n\n\n\nДолго ждал этого фильма, посмотрел все...
# 27  \n\n\n\nСегодня свершилось то, чего лично я жд...
# 28  \n\n\n\nИндийский режиссер Найт Шьямалан нагля...
# 29  \n\n\n\nМой друг просто фанатеет от мультсериа...
# 30  \n\n\n\nФильм М. Найта. Шьямалана 'Повелитель ...
# 31  \n\n\n\nНачнем с того, что я не являюсь фанато...
# 32  \n\n\n\nВот все, что я могу сказать о фильме.\...

# %%
df_bad_air.to_csv('Last Airbender_all_reviews_bad.txt', sep='\t', index=False) # заново не выгружала

# %% [markdown]
# ## Good reviews (129) (выгружены)

# %%
kinopoisk_url_list_good_air = []


for page_g1 in range(1, 14):
    url_page_good1 = f'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/{page_g1}/'
    kinopoisk_url_list_good_air.append(url_page_good1)
print(kinopoisk_url_list_good_air)
# Out:
# ['https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/9/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/10/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/11/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/12/', 'https://www.kinopoisk.ru/film/417855/reviews/ord/date/status/good/perpage/10/page/13/']

# %%
url_good1 = kinopoisk_url_list_good_air[12]

def review_good_parsing_air(url_good1):
    page_good1 = requests.get(url_good1)
    soup_good1 = BeautifulSoup(page_good1.text, features = 'html.parser')
    review_content_good1 = soup_good1.find_all('tbody')
    review_good1 = [good1.text for good1 in review_content_good1]
    final_review_good1 = ' '.join(review_good1)
    return final_review_good1
#print(review_good_parsing_air(url_good1))

# %%
from time import sleep

all_reviews_good_air = [] # список с положительные отзывами

for g1 in kinopoisk_url_list_good_air:
    try:
        rev_good1 = review_good_parsing_air(g1)
        all_reviews_good_air.append(rev_good1)
        sleep (3)
    except:
        print(g1) #try, except показывает, какая ссылка ломает парсер

# %%
df_good_air = pd.DataFrame(all_reviews_good_air)
df_good_air
# Out:
#                                                     0
# 0   \n\n\n\nЕсли вы фанат популярного мультсериала...
# 1   \n\n\n\nНедавно совсем посмотрела. Сразу скажу...
# 2   \n\n\n\nСадясь за просмотр данного фильма, я з...
# 3   \n\n\n\nКогда индус берутся экранизировать аме...
# 4   \n\n\n\nХороший фильм, единственное, что сильн...
# 5   \n\n\n\nСкажу сразу - на картину был настроен ...
# 6   \n\n\n\nВ ожидании «Повелителей стихий» я проб...
# 7   \n\n\n\nНе так давно увидела по телевизору мул...
# 8   \n\n\n\nКаждый имеет право иметь свое собствен...
# 9   \n\n\n\nИдя на фильм я имела небольшое предста...
# 10  \n\n\n\nЭтого фильма я ждала с большим нетерпе...
# 11  \n\n\n\nПомню как в детстве играли в игру и во...
# 12  \n\n\n\nНе смотря на то, что я никогда не явля...

# %%
df_good_air.to_csv('Last Airbender_all_reviews_good.txt', sep='\t', index=False) # заново не выгружала

# %% [markdown]
# # Фантастические твари: Преступления Грин-де-Вальда

# %% [markdown]
# ## Bad reviews (71) (выгружены)

# %%
page_link2 = 'https://www.kinopoisk.ru/film/843479/reviews/'
response2 = requests.get(page_link2, headers={'User-Agent': UserAgent().chrome})
url2 = 'https://www.kinopoisk.ru/film/843479/reviews/' 

r2 = requests.get(url2) # загружаем страницу по ссылке
print(r2.status_code)

if r2.status_code == 200:
    soup2 = BeautifulSoup(r2.text, features="html.parser")
    #print(soup2.prettify())
else:
    print("ERROR")
# Out:
# 200

# %%
kinopoisk_url_list_bad_creature = []


for page_b2 in range(1, 9):
    url_page_bad2 = f'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/bad/perpage/10/page/{page_b2}/'
    kinopoisk_url_list_bad_creature.append(url_page_bad2)
print(kinopoisk_url_list_bad_creature)
# Out:
# ['https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/bad/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/bad/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/bad/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/bad/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/bad/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/bad/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/bad/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/bad/perpage/10/page/8/']

# %%
url_bad2 = kinopoisk_url_list_bad_creature[3]

def review_bad_parsing_creature(url_bad2):
    page_bad2 = requests.get(url_bad2)
    soup_bad2 = BeautifulSoup(page_bad2.text, features = 'html.parser')
    review_content_bad2 = soup_bad2.find_all('tbody')
    review_bad2 = [bad2.text for bad2 in review_content_bad2]
    final_review_bad2 = ' '.join(review_bad2)
    return final_review_bad2
#print(review_bad_parsing_creature(url_bad2))

# %%
from time import sleep

all_reviews_bad_creature = [] # список с положительными отзывами

for b2 in kinopoisk_url_list_bad_creature:
    try:
        rev_bad2 = review_bad_parsing_creature(b2)
        all_reviews_bad_creature.append(rev_bad2)
        sleep(5)
    except:
        print(b2) #try, except показывает, какая ссылка ломает парсер

# %%
df_bad_creature = pd.DataFrame(all_reviews_bad_creature)
df_bad_creature
# Out:
#                                                    0
# 0  \n\n\n\n'Фантастические твари: Преступления Гр...
# 1  \n\n\n\nТрейлер фильма был зрелищный и интригу...
# 2  \n\n\n\nМногие моего возраста буквально выросл...
# 3  \n\n\n\nФантастические твари: Преступления Гри...
# 4  \n\n\n\nПытаться объяснить, что такое «Преступ...
# 5  \n\n\n\nДва года назад для фанатов волшебной в...
# 6  \n\n\n\nСразу к делу и по существу! За два час...
# 7  \n\n\n\nСобственно говоря, давно уже известно,...

# %%
df_bad_creature.to_csv('Fantastic_Creature_all_reviews_bad.txt', sep='\t', index=False) # заново не выгружала

# %% [markdown]
# ## Good reviews (75) (выгружены)

# %%
kinopoisk_url_list_good_creature = []


for page_g2 in range(1, 9):
    url_page_good2 = f'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/good/perpage/10/page/{page_g2}/'
    kinopoisk_url_list_good_creature.append(url_page_good2)
print(kinopoisk_url_list_good_creature)
# Out:
# ['https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/good/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/good/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/good/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/good/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/good/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/good/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/good/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/843479/reviews/ord/date/status/good/perpage/10/page/8/']

# %%
url_good2 = kinopoisk_url_list_good_creature[0]

def review_good_parsing_creature(url_good2):
    page_good2 = requests.get(url_good2)
    soup_good2 = BeautifulSoup(page_good2.text, features = 'html.parser')
    review_content_good2 = soup_good2.find_all('tbody')
    review_good2 = [good2.text for good2 in review_content_good2]
    final_review_good2 = ' '.join(review_good2)
    return final_review_good2
#print(review_good_parsing_creature(url_good2))

# %%
from time import sleep

all_reviews_good_creature = [] # список с положительными отзывами

for g2 in kinopoisk_url_list_good_creature:
    try:
        rev_good2 = review_good_parsing_creature(g2)
        all_reviews_good_creature.append(rev_good2)
        sleep(5)
    except:
        print(g2) #try, except показывает, какая ссылка ломает парсер

# %%
df_good_creature = pd.DataFrame(all_reviews_good_creature)
df_good_creature
# Out:
#                                                    0
# 0  \n\n\n\nВторая часть понравилась мне меньше пе...
# 1  \n\n\n\nНачну с того, что Фантастические Твари...
# 2  \n\n\n\nЯ, как не фанат Гарри Поттера, с увере...
# 3  \n\n\n\nКак Поттероман сразу скажу, что фильм ...
# 4  \n\n\n\nПосмотрела “Преступления Грин-де-вальд...
# 5  \n\n\n\nФильм Фантастические твари: Преступлен...
# 6  \n\n\n\nНовый фильм по вселенной Гарри Поттера...
# 7  \n\n\n\nОх и ждал я этот фильм. Первая часть м...

# %%
df_good_creature.to_csv('Fantastic_Creature_all_reviews_good.txt', sep='\t', index=False) # заново не выгружала

# %% [markdown]
# # Барби

# %% [markdown]
# ## Bad reviews (66) (выгружены)

# %%
page_link3 = 'https://www.kinopoisk.ru/film/478052/reviews/'
response3 = requests.get(page_link3, headers={'User-Agent': UserAgent().chrome})
url3 = 'https://www.kinopoisk.ru/film/478052/reviews/' 

r3 = requests.get(url3) # загружаем страницу по ссылке
print(r3.status_code)

if r3.status_code == 200:
    soup3 = BeautifulSoup(r3.text, features="html.parser")
    #print(soup3.prettify())
else:
    print("ERROR")
# Out:
# 200

# %%
kinopoisk_url_list_bad_barbie = []


for page_b3 in range(1, 8):
    url_page_bad3 = f'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/bad/perpage/10/page/{page_b3}/'
    kinopoisk_url_list_bad_barbie.append(url_page_bad3)
print(kinopoisk_url_list_bad_barbie)
# Out:
# ['https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/bad/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/bad/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/bad/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/bad/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/bad/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/bad/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/bad/perpage/10/page/7/']

# %%
url_bad3 = kinopoisk_url_list_bad_barbie[3]

def review_bad_parsing_barbie(url_bad3):
    page_bad3 = requests.get(url_bad3)
    soup_bad3 = BeautifulSoup(page_bad3.text, features = 'html.parser')
    review_content_bad3 = soup_bad3.find_all('tbody')
    review_bad3 = [bad3.text for bad3 in review_content_bad3]
    final_review_bad3 = ' '.join(review_bad3)
    return final_review_bad3
#print(review_bad_parsing_barbie(url_bad3))

# %%
from time import sleep

all_reviews_bad_barbie = [] # список с отрицательными отзывами

for b3 in kinopoisk_url_list_bad_barbie:
    try:
        rev_bad3 = review_bad_parsing_barbie(b3)
        all_reviews_bad_barbie.append(rev_bad3)
        sleep (5)
    except:
        print(b3) #try, except показывает, какая ссылка ломает парсер

# %%
df_bad_barbie = pd.DataFrame(all_reviews_bad_barbie)
df_bad_barbie
# Out:
#                                                    0
# 0  \n\n\n\nВ очередной раз приходит убеждение, чт...
# 1  \n\n\n\nПервые минуты фильма «Барби» показываю...
# 2  \n\n\n\nНепрофессиональная халтура.\n\r\nИ вот...
# 3  \n\n\n\nЧрезмерно линейная и размазанная в хро...
# 4  \n\n\n\nВыше есть комментарий \'Отвратное кино...
# 5  \n\n\n\nИнтерес к фильму возник из-за красочны...
# 6  \n\n\n\nНе скажу что идея провальная, но реали...

# %%
df_bad_barbie.to_csv('Parsing_Barbie_bad_fin.txt', sep='\t', index=False)

# %% [markdown]
# ## Good reviews (58) (выгружены)

# %%
kinopoisk_url_list_good_barbie = []


for page_g3 in range(1, 7):
    url_page_good3 = f'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/good/perpage/10/page/{page_g3}/'
    kinopoisk_url_list_good_barbie.append(url_page_good3)
print(kinopoisk_url_list_good_barbie)
# Out:
# ['https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/good/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/good/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/good/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/good/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/good/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/478052/reviews/ord/date/status/good/perpage/10/page/6/']

# %%
url_good3 = kinopoisk_url_list_good_barbie[3]

def review_good_parsing_barbie(url_good3):
    page_good3 = requests.get(url_good3)
    soup_good3 = BeautifulSoup(page_good3.text, features = 'html.parser')
    review_content_good3 = soup_good3.find_all('tbody')
    review_good3 = [good3.text for good3 in review_content_good3]
    final_review_good3 = ' '.join(review_good3)
    return final_review_good3
#print(review_good_parsing_barbie(url_good3))

# %%
from time import sleep

all_reviews_good_barbie = [] # список с положительными отзывами

for g3 in kinopoisk_url_list_good_barbie:
    try:
        rev_good3 = review_good_parsing_barbie(g3)
        all_reviews_good_barbie.append(rev_good3)
        sleep (3)
    except:
        print(g3) #try, except показывает, какая ссылка ломает парсер

# %%
df_good_barbie = pd.DataFrame(all_reviews_good_barbie)
df_good_barbie
# Out:
#                                                    0
# 0  \n\n\n\nДумаю мало кто будет спорить с тем, чт...
# 1  \n\n\n\nЖизнь течет своим чередом. Возникают н...
# 2  \n\n\n\nЕще во время первого просмотра фильма ...
# 3  \n\n\n\nВ Кене Райана Гослинга больше жизни, ч...
# 4  \n\n\n\nВ эпоху расцвета мысль о том, что чело...
# 5  \n\n\n\nГениальный фильм от не менее гениально...

# %%
df_good_barbie.to_csv('Parsing_Barbie_good_fin.txt', sep='\t', index=False)

# %% [markdown]
# # Охотники за привидениями 2016

# %% [markdown]
# ## Bad reviews (79) (выгружены)

# %%
page_link4 = 'https://www.kinopoisk.ru/film/425673/reviews/'
response4 = requests.get(page_link4, headers={'User-Agent': UserAgent().chrome})
url4 = 'https://www.kinopoisk.ru/film/425673/reviews/' 

r4 = requests.get(url4) # загружаем страницу по ссылке
print(r4.status_code)

if r4.status_code == 200:
    soup4 = BeautifulSoup(r4.text, features="html.parser")
    #print(soup4.prettify())
else:
    print("ERROR")
# Out:
# 200

# %%
kinopoisk_url_list_bad_ghost = []


for page_b4 in range(1, 9):
    url_page_bad4 = f'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/bad/perpage/10/page/{page_b4}/'
    kinopoisk_url_list_bad_ghost.append(url_page_bad4)
print(kinopoisk_url_list_bad_ghost)
# Out:
# ['https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/bad/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/bad/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/bad/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/bad/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/bad/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/bad/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/bad/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/bad/perpage/10/page/8/']

# %%
url_bad4 = kinopoisk_url_list_bad_ghost[3]

def review_bad_parsing_ghost(url_bad4):
    page_bad4 = requests.get(url_bad4)
    soup_bad4 = BeautifulSoup(page_bad4.text, features = 'html.parser')
    review_content_bad4 = soup_bad4.find_all('tbody')
    review_bad4 = [bad4.text for bad4 in review_content_bad4]
    final_review_bad4 = ' '.join(review_bad4)
    return final_review_bad4
#print(review_bad_parsing_ghost(url_bad4))

# %%
from time import sleep

all_reviews_bad_ghost = [] # список с отрицательными отзывами

for b4 in kinopoisk_url_list_bad_ghost:
    try:
        rev_bad4 = review_bad_parsing_ghost(b4)
        all_reviews_bad_ghost.append(rev_bad4)
        sleep(10)
    except:
        print(b4) #try, except показывает, какая ссылка ломает парсер

# %%
df_bad_ghost = pd.DataFrame(all_reviews_bad_ghost)
df_bad_ghost
# Out:
#                                                    0
# 0  \n\n\n\nЭто очень плохой фильм. Абсолютно во в...
# 1  \n\n\n\nЯ вообще не понял, чем руководствовали...
# 2  \n\n\n\nЕщё на стадии анонса “женский” ремейк ...
# 3  \n\n\n\nРемейки культовых старых картин — неиз...
# 4  \n\n\n\nУзнав о том, что будут перезапускать ф...
# 5  \n\n\n\nОхота Полу Фигу и Мелиссе МакКарти с к...
# 6  \n\n\n\nОхотники За Привидениями 2016 года по ...
# 7  \n\n\n\nСходив на новых 'охотников за приведен...

# %%
df_bad_ghost.to_csv('Ghostbusters_all_reviews_bad.txt', sep='\t', index=False) # заново не выгружала

# %% [markdown]
# ## Good reviews (68) (выгружены)

# %%
kinopoisk_url_list_good_ghost = []


for page_g4 in range(1, 8):
    url_page_good4 = f'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/good/perpage/10/page/{page_g4}/'
    kinopoisk_url_list_good_ghost.append(url_page_good4)
print(kinopoisk_url_list_good_ghost)
# Out:
# ['https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/good/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/good/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/good/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/good/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/good/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/good/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/425673/reviews/ord/date/status/good/perpage/10/page/7/']

# %%
url_good4 = kinopoisk_url_list_good_ghost[0]

def review_good_parsing_ghost(url_good4):
    page_good4 = requests.get(url_good4)
    soup_good4 = BeautifulSoup(page_good4.text, features = 'html.parser')
    review_content_good4 = soup_good4.find_all('tbody')
    review_good4 = [good4.text for good4 in review_content_good4]
    final_review_good4 = ' '.join(review_good4)
    return final_review_good4
#print(review_good_parsing_ghost(url_good4))

# %%
from time import sleep

all_reviews_good_ghost = [] # список с положительными отзывами

for g4 in kinopoisk_url_list_good_ghost:
    try:
        rev_good4 = review_good_parsing_ghost(g4)
        all_reviews_good_ghost.append(rev_good4)
        sleep(3)
    except:
        print(g4) #try, except показывает, какая ссылка ломает парсер

# %%
df_good_ghost = pd.DataFrame(all_reviews_good_ghost)
df_good_ghost
# Out:
#                                                    0
# 0  \n\n\n\nС самого начала я испытывал к фильму с...
# 1  \n\n\n\n1. Они сделали все что смогли.\n\n2. О...
# 2  \n\n\n\nЧестно, как и многие-другие, увидев тр...
# 3  \n\n\n\nТо чувство, когда поливать негативом ф...
# 4  \n\n\n\nКогда- то 30 лет назад жили были. .. Ш...
# 5  \n\n\n\nЯ в большом недоумении по поводу рейти...
# 6  \n\n\n\nЧерт возьми, вторая часть знаменитой д...

# %%
df_good_ghost.to_csv('Parsing_Ghostbusters_good_fin.txt', sep='\t', index=False)

# %% [markdown]
# # Муви 43

# %% [markdown]
# ## Bad reviews (108) (выгружены)

# %%
page_link5 = 'https://www.kinopoisk.ru/film/432725/reviews/'
response5 = requests.get(page_link5, headers={'User-Agent': UserAgent().chrome})
url5 = 'https://www.kinopoisk.ru/film/432725/reviews/' 

r5 = requests.get(url5) # загружаем страницу по ссылке
print(r5.status_code)

if r5.status_code == 200:
    soup5 = BeautifulSoup(r5.text, features="html.parser")
    #print(soup5.prettify())
else:
    print("ERROR")
# Out:
# 200

# %%
kinopoisk_url_list_bad_movie = []


for page_b5 in range(1, 12):
    url_page_bad5 = f'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/{page_b5}/'
    kinopoisk_url_list_bad_movie.append(url_page_bad5)
print(kinopoisk_url_list_bad_movie)
# Out:
# ['https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/9/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/10/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/bad/perpage/10/page/11/']

# %%
url_bad5 = kinopoisk_url_list_bad_movie[3]

def review_bad_parsing_movie(url_bad5):
    page_bad5 = requests.get(url_bad5)
    soup_bad5 = BeautifulSoup(page_bad5.text, features = 'html.parser')
    review_content_bad5 = soup_bad5.find_all('tbody')
    review_bad5 = [bad5.text for bad5 in review_content_bad5]
    final_review_bad5 = ' '.join(review_bad5)
    return final_review_bad5
#print(review_bad_parsing_movie(url_bad5))

# %%
from time import sleep

all_reviews_bad_movie = [] # список с отрицательными отзывами

for b5 in kinopoisk_url_list_bad_movie:
    try:
        rev_bad5 = review_bad_parsing_movie(b5)
        all_reviews_bad_movie.append(rev_bad5)
        sleep(10)
    except:
        print(b5) #try, except показывает, какая ссылка ломает парсер

# %%
df_bad_movie = pd.DataFrame(all_reviews_bad_movie)
df_bad_movie
# Out:
#                                                     0
# 0   \n\n\n\nДолго думал, стоит ли писать трехсотую...
# 1   \n\n\n\nНа эту «комедию» меня затащил друг, об...
# 2   \n\n\n\nМоей целью после просмотра фильма стал...
# 3   \n\n\n\nЯ услышала про этот фильм от своего мл...
# 4   \n\n\n\nМногие знакомые советовали посмотреть ...
# 5   \n\n\n\nДвадцать пять известнейших актеров раз...
# 6   \n\n\n\nУдивительно как порой определенные тре...
# 7   \n\n\n\nРебята, это провал... нет, это не прос...
# 8   \n\n\n\nВульгарное, пошлое, тупое кино, рассчи...
# 9   \n\n\n\nПосле просмотра данного фильма, которы...
# 10  \n\n\n\nВ кино я шёл вообще без всяких ожидани...

# %%
df_bad_movie.to_csv('Movie43_all_reviews_bad.txt', sep='\t', index=False) # заново не выгружала

# %% [markdown]
# ## Good reviews (117) (выгружены)

# %%
kinopoisk_url_list_good_movie = []


for page_g5 in range(1, 13):
    url_page_good5 = f'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/{page_g5}/'
    kinopoisk_url_list_good_movie.append(url_page_good5)
print(kinopoisk_url_list_good_movie)
# Out:
# ['https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/9/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/10/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/11/', 'https://www.kinopoisk.ru/film/432725/reviews/ord/date/status/good/perpage/10/page/12/']

# %%
url_good5 = kinopoisk_url_list_good_movie[3]

def review_good_parsing_movie(url_good5):
    page_good5 = requests.get(url_good5)
    soup_good5 = BeautifulSoup(page_good5.text, features = 'html.parser')
    review_content_good5 = soup_good5.find_all('tbody')
    review_good5 = [good5.text for good5 in review_content_good5]
    final_review_good5 = ' '.join(review_good5)
    return final_review_good5
#print(review_good_parsing_movie(url_good5))

# %%
from time import sleep

all_reviews_good_movie = [] # список с положительными отзывами

for g5 in kinopoisk_url_list_good_movie:
    try:
        rev_good5 = review_good_parsing_movie(g5)
        all_reviews_good_movie.append(rev_good5)
        sleep(5)
    except:
        print(g5) #try, except показывает, какая ссылка ломает парсер

# %%
df_good_movie = pd.DataFrame(all_reviews_good_movie)
df_good_movie
# Out:
#                                                     0
# 0   \n\n\n\nВ начале 2000-х годов жанр американски...
# 1   \n\n\n\nПосле всего, что я слышала об этом фил...
# 2   \n\n\n\nВеликолепный фильм.\n\r\nДолжен призна...
# 3   \n\n\n\nПосле просмотра 'Очень страшное кино' ...
# 4   \n\n\n\nНу что тут сказать. Пошло. Дико. Можно...
# 5   \n\n\n\nОдин только актерский состав говорит о...
# 6   \n\n\n\nИногда появляются такие кино-проекты, ...
# 7   \n\n\n\nКак же смешно читать или слушать отриц...
# 8   \n\n\n\nДанный фильм представляется мне ничем ...
# 9   \n\n\n\nВыходя из зала, я думала, что ничего д...
# 10  \n\n\n\nЭтот фильм действительно удивит любого...
# 11  \n\n\n\nНачнем с того, что фильм красив, несмо...

# %%
df_good_movie.to_csv('Parsing_Movie43_good_fin.txt', sep='\t', index=False)

# %% [markdown]
# # 50 оттенков серого

# %% [markdown]
# ## Bad reviews (267) (выгружены)

# %%
page_link6 = 'https://www.kinopoisk.ru/film/688832/reviews/'
response6 = requests.get(page_link6, headers={'User-Agent': UserAgent().chrome})
url6 = 'https://www.kinopoisk.ru/film/688832/reviews/' 

r6 = requests.get(url6) # загружаем страницу по ссылке
print(r6.status_code)

if r6.status_code == 200:
    soup6 = BeautifulSoup(r6.text, features="html.parser")
    #print(soup6.prettify())
else:
    print("ERROR")
# Out:
# 200

# %%
kinopoisk_url_list_bad_shades = []


for page_b6 in range(1, 28):
    url_page_bad6 = f'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/{page_b6}/'
    kinopoisk_url_list_bad_shades.append(url_page_bad6)
print(kinopoisk_url_list_bad_shades)
# Out:
# ['https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/9/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/10/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/11/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/12/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/13/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/14/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/15/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/16/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/17/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/18/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/19/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/20/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/21/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/22/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/23/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/24/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/25/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/26/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/bad/perpage/10/page/27/']

# %%
url_bad6 = kinopoisk_url_list_bad_shades[0]

def review_bad_parsing_shades(url_bad6):
    page_bad6 = requests.get(url_bad6)
    soup_bad6 = BeautifulSoup(page_bad6.text, features = 'html.parser')
    review_content_bad6 = soup_bad6.find_all('tbody')
    review_bad6 = [bad6.text for bad6 in review_content_bad6]
    final_review_bad6 = ' '.join(review_bad6)
    return final_review_bad6
#print(review_bad_parsing_shades(url_bad6))

# %%
from time import sleep

all_reviews_bad_shades = [] # список с отрицательными отзывами

for b6 in kinopoisk_url_list_bad_shades:
    try:
        rev_bad6 = review_bad_parsing_shades(b6)
        all_reviews_bad_shades.append(rev_bad6)
        sleep(5)
    except:
        print(b6) #try, except показывает, какая ссылка ломает парсер

# %%
df_bad_shades = pd.DataFrame(all_reviews_bad_shades)
df_bad_shades
# Out:
#                                                     0
# 0   \n\n\n\nДоброго времени суток для всех, кто ви...
# 1   \n\n\n\nПервое, на что хочу обратить внимание,...
# 2   \n\n\n\nПодобно авторам многих рецензий, я тож...
# 3   \n\n\n\nНичего нового, вероятно, в моей реценз...
# 4   \n\n\n\nНа этот фильм я бы никогда не потратил...
# 5   \n\n\n\nМое отношение к книге\n\r\nКнига «50 о...
# 6   \n\n\n\nНачав с небольшого анализа самой книги...
# 7   \n\n\n\nНачнём по порядку. Я читал все 3 книги...
# 8   \n\n\n\nТак много крика было вокруг данного фи...
# 9   \n\n\n\nПро 'Пятьдесят оттенков серого' сейчас...
# 10  \n\n\n\nФильм, как и книга, вызывает один спло...
# 11  \n\n\n\nЯ читала книгу. Я не эксперт и не крит...
# 12  \n\n\n\nВ этом обзоре хотел бы поделиться свои...
# 13  \n\n\n\nПрежде чем высказаться про этот 'шедев...
# 14  \n\n\n\nКак и предполагалось, экранная версия ...
# 15  \n\n\n\nПоддавшись всеобщей шумихе, 'приоткрыл...
# 16  \n\n\n\nФеномен пятидесяти оттенков загадочен ...
# 17  \n\n\n\nКогда только появилась информация о то...
# 18  \n\n\n\nИ так в начале немного о наболевшем в ...
# 19  \n\n\n\nИ угораздило же меня посмотреть '50 от...
# 20  \n\n\n\nЕсли честно, про существование книги '...
# 21  \n\n\n\nШли с подругой на этот фильм, ясно осо...
# 22  \n\n\n\nКогда я сегодня пошла в кино, я соверш...
# 23  \n\n\n\nФильм ни о чем!!! Сюжетной линии практ...
# 24  \n\n\n\nСходил в кинотеатр на фильм '50 оттенк...
# 25  \n\n\n\nЕсли кратко:  фильм достоин книги.  На...
# 26  \n\n\n\nЯ, наверное один из меньшинства мужчин...

# %%
df_bad_shades.to_csv('Shades_all_reviews_bad.txt', sep='\t', index=False) # заново не выгружала

# %% [markdown]
# ## Good reviews (192) выгружены

# %%
kinopoisk_url_list_good_shades = []


for page_g6 in range(1, 21):
    url_page_good6 = f'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/{page_g6}/'
    kinopoisk_url_list_good_shades.append(url_page_good6)
print(kinopoisk_url_list_good_shades)
# Out:
# ['https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/9/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/10/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/11/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/12/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/13/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/14/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/15/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/16/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/17/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/18/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/19/', 'https://www.kinopoisk.ru/film/688832/reviews/ord/date/status/good/perpage/10/page/20/']

# %%
url_good6 = kinopoisk_url_list_good_shades[0]

def review_good_parsing_shades(url_good6):
    page_good6 = requests.get(url_good6)
    soup_good6 = BeautifulSoup(page_good6.text, features = 'html.parser')
    review_content_good6 = soup_good6.find_all('tbody')
    review_good6 = [good6.text for good6 in review_content_good6]
    final_review_good6 = ' '.join(review_good6)
    return final_review_good6
#print(review_good_parsing_shades(url_good6))

# %%
from time import sleep

all_reviews_good_shades = [] # список с положительными отзывами

for g6 in kinopoisk_url_list_good_shades:
    try:
        rev_good6 = review_good_parsing_shades(g6)
        all_reviews_good_shades.append(rev_good6)
        sleep(5)
    except:
        print(g6) #try, except показывает, какая ссылка ломает парсер

# %%
df_good_shades = pd.DataFrame(all_reviews_good_shades)
df_good_shades
# Out:
#                                                     0
# 0   \n\n\n\nУ фильма, как и у книги, есть много ми...
# 1   \n\n\n\nПоди разбери, с чего хочется определен...
# 2   \n\n\n\nПосле недавнего просмотра данного филь...
# 3   \n\n\n\nОтлично снятый, красивый, волнующий фи...
# 4   \n\n\n\nНашумевший рассказ 50 оттенков серого ...
# 5   \n\n\n\nВсем доброго времени суток, настал мой...
# 6   \n\n\n\nДо просмотра фильма «50 оттенков серог...
# 7   \n\n\n\nУважаемые зрители, начнём! Я не понасл...
# 8   \n\n\n\nПятьдесят оттенков серого. Эта трилоги...
# 9   \n\n\n\nСмотря на краснеющий рейтинг этого фил...
# 10  \n\n\n\nНемного припозднилась с просмотром, та...
# 11  \n\n\n\n«Пятьдесят оттенков серого» — нашумевш...
# 12  \n\n\n\nПосле своего выхода книга Пятьдесят от...
# 13  \n\n\n\nНачну с того, что я попала на до премь...
# 14  \n\n\n\nКаждый, кто читал книгу и оценил ее дл...
# 15  \n\n\n\nПочему же все-таки столько негатива? Ч...
# 16  \n\n\n\nСразу скажу, что с первоисточником я н...
# 17  \n\n\n\n1) ВСТУПЛЕНИЕ. Сразу оговорюсь, что на...
# 18  \n\n\n\nЯ с нетерпением ждал выхода фильма '50...
# 19  \n\n\n\nНе буду рассказывать сюжет, потому что...

# %%
df_good_shades.to_csv('Parsing_Shades_good_fin.txt', sep='\t', index=False)

# %% [markdown]
# # Папины дочки (2007-2013)

# %% [markdown]
# ## Bad reviews (58) (выгружены)

# %%
page_link7 = 'https://www.kinopoisk.ru/film/394047/reviews/'
response7 = requests.get(page_link7, headers={'User-Agent': UserAgent().chrome})
url7 = 'https://www.kinopoisk.ru/film/394047/reviews/' 

r7 = requests.get(url7) # загружаем страницу по ссылке
print(r7.status_code)

if r7.status_code == 200:
    soup7 = BeautifulSoup(r7.text, features="html.parser")
    #print(soup7.prettify())
else:
    print("ERROR")
# Out:
# 200

# %%
kinopoisk_url_list_bad_daughter = []


for page_b7 in range(1, 7):
    url_page_bad7 = f'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/bad/perpage/10/page/{page_b7}/'
    kinopoisk_url_list_bad_daughter.append(url_page_bad7)
print(kinopoisk_url_list_bad_daughter)
# Out:
# ['https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/bad/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/bad/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/bad/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/bad/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/bad/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/bad/perpage/10/page/6/']

# %%
url_bad7 = kinopoisk_url_list_bad_daughter[0]

def review_bad_parsing_daughter(url_bad7):
    page_bad7 = requests.get(url_bad7)
    soup_bad7 = BeautifulSoup(page_bad7.text, features = 'html.parser')
    review_content_bad7 = soup_bad7.find_all('tbody')
    review_bad7 = [bad7.text for bad7 in review_content_bad7]
    final_review_bad7 = ' '.join(review_bad7)
    return final_review_bad7
#print(review_bad_parsing_daughter(url_bad7))

# %%
from time import sleep

all_reviews_bad_daughter = [] # список с отрицательными отзывами

for b7 in kinopoisk_url_list_bad_daughter:
    try:
        rev_bad7 = review_bad_parsing_daughter(b7)
        all_reviews_bad_daughter.append(rev_bad7)
        sleep(5)
    except:
        print(b7) #try, except показывает, какая ссылка ломает парсер

# %%
df_bad_daughter = pd.DataFrame(all_reviews_bad_daughter)
df_bad_daughter
# Out:
#                                                    0
# 0  \n\n\n\nСериал 'Папины дочки' я начал смотреть...
# 1  \n\n\n\nПо поводу новых серий 'маминых дочек' ...
# 2  \n\n\n\nСериал 'Папины дочки' считается одним ...
# 3  \n\n\n\nЧто можно такого тут написать? Все что...
# 4  \n\n\n\nА ведь неплохая идея то была. Первый с...
# 5  \n\n\n\nДля начала хочу сказать, что сериал пр...

# %%
df_bad_daughter.to_csv('Parsing_Daughter_bad_fin.txt', sep='\t', index=False)

# %% [markdown]
# ## Good reviews (65) (выгружены)

# %%
kinopoisk_url_list_good_daughter = []


for page_g7 in range(1, 8):
    url_page_good7 = f'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/good/perpage/10/page/{page_g7}/'
    kinopoisk_url_list_good_daughter.append(url_page_good7)
print(kinopoisk_url_list_good_daughter)
# Out:
# ['https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/good/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/good/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/good/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/good/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/good/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/good/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/394047/reviews/ord/date/status/good/perpage/10/page/7/']

# %%
url_good7 = kinopoisk_url_list_good_daughter[0]

def review_good_parsing_daughter(url_good7):
    page_good7 = requests.get(url_good7)
    soup_good7 = BeautifulSoup(page_good7.text, features = 'html.parser')
    review_content_good7 = soup_good7.find_all('tbody')
    review_good7 = [good7.text for good7 in review_content_good7]
    final_review_good7 = ' '.join(review_good7)
    return final_review_good7
#print(review_good_parsing_daughter(url_good7))

# %%
from time import sleep

all_reviews_good_daughter = [] # список с положительными отзывами

for g7 in kinopoisk_url_list_good_daughter:
    try:
        rev_good7 = review_good_parsing_daughter(g7)
        all_reviews_good_daughter.append(rev_good7)
        sleep(5)
    except:
        print(g7) #try, except показывает, какая ссылка ломает парсер

# %%
df_good_daughter = pd.DataFrame(all_reviews_good_daughter)
df_good_daughter
# Out:
#                                                    0
# 0  \n\n\n\nИстория про многодетного отца, который...
# 1  \n\n\n\nТакой уж я человек, что не люблю комед...
# 2  \n\n\n\nНачала смотреть сериал, когда приходил...
# 3  \n\n\n\nЯ лично просмотрела все серии этого си...
# 4  \n\n\n\n'Папины дочки' - это непревзойденный ш...
# 5  \n\n\n\nСериал. Мне, например, это слово напом...
# 6  \n\n\n\nМама вернулась. Зато папа уехал. Все с...

# %%
df_good_daughter.to_csv('Parsing_Daughter_good_fin.txt', sep='\t', index=False)

# %% [markdown]
# # Адмиралъ

# %% [markdown]
# ## Bad reviews (85) (выгружены)

# %%
page_link8 = 'https://www.kinopoisk.ru/film/280938/reviews/'
response8 = requests.get(page_link8, headers={'User-Agent': UserAgent().chrome})
url8 = 'https://www.kinopoisk.ru/film/280938/reviews/' 

r8 = requests.get(url8) # загружаем страницу по ссылке
print(r8.status_code)

if r8.status_code == 200:
    soup8 = BeautifulSoup(r8.text, features="html.parser")
    #print(soup8.prettify())
else:
    print("ERROR")
# Out:
# 200

# %%
kinopoisk_url_list_bad_admiral = []


for page_b8 in range(1, 10):
    url_page_bad8 = f'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/bad/perpage/10/page/{page_b8}/'
    kinopoisk_url_list_bad_admiral.append(url_page_bad8)
print(kinopoisk_url_list_bad_admiral)
# Out:
# ['https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/bad/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/bad/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/bad/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/bad/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/bad/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/bad/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/bad/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/bad/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/bad/perpage/10/page/9/']

# %%
url_bad8 = kinopoisk_url_list_bad_admiral[0]

def review_bad_parsing_admiral(url_bad8):
    page_bad8 = requests.get(url_bad8)
    soup_bad8 = BeautifulSoup(page_bad8.text, features = 'html.parser')
    review_content_bad8 = soup_bad8.find_all('tbody')
    review_bad8 = [bad8.text for bad8 in review_content_bad8]
    final_review_bad8 = ' '.join(review_bad8)
    return final_review_bad8
#print(review_bad_parsing_admiral(url_bad8))

# %%
from time import sleep

all_reviews_bad_admiral = [] # список с отрицательными отзывами

for b8 in kinopoisk_url_list_bad_admiral:
    try:
        rev_bad8 = review_bad_parsing_admiral(b8)
        all_reviews_bad_admiral.append(rev_bad8)
        sleep(5)
    except:
        print(b8) #try, except показывает, какая ссылка ломает парсер

# %%
df_bad_admiral = pd.DataFrame(all_reviews_bad_admiral)
df_bad_admiral
# Out:
#                                                    0
# 0  \n\n\n\nВы тоже, включая фильм о Колчаке, в оп...
# 1  \n\n\n\nЯ ожидала несколько иного от этого фил...
# 2  \n\n\n\nМне тут подсказывают, что про этот фил...
# 3  \n\n\n\nСейчас на экраны выпустили 10серийный ...
# 4  \n\n\n\nУже на 5й минуте фильма, в глаза броса...
# 5  \n\n\n\nРеванш проигравших\n\r\nЧестно говоря,...
# 6  \n\n\n\nИ вот долгожданный фильм наконец-то пр...
# 7  \n\n\n\nТема белого движения – одна из самых и...
# 8  \n\n\n\nПиар у проекта был шикарен. На каждом ...

# %%
df_bad_admiral.to_csv('Parsing_Admiral_bad_fin.txt', sep='\t', index=False)

# %% [markdown]
# ## Good reviews (199) (выгружены)

# %%
kinopoisk_url_list_good_admiral = []


for page_g8 in range(1, 21):
    url_page_good8 = f'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/{page_g8}/'
    kinopoisk_url_list_good_admiral.append(url_page_good8)
print(kinopoisk_url_list_good_admiral)
# Out:
# ['https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/9/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/10/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/11/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/12/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/13/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/14/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/15/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/16/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/17/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/18/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/19/', 'https://www.kinopoisk.ru/film/280938/reviews/ord/date/status/good/perpage/10/page/20/']

# %%
url_good8 = kinopoisk_url_list_good_admiral[0]

def review_good_parsing_admiral(url_good8):
    page_good8 = requests.get(url_good8)
    soup_good8 = BeautifulSoup(page_good8.text, features = 'html.parser')
    review_content_good8 = soup_good8.find_all('tbody')
    review_good8 = [good8.text for good8 in review_content_good8]
    final_review_good8 = ' '.join(review_good8)
    return final_review_good8
#print(review_good_parsing_admiral(url_good8))

# %%
from time import sleep

all_reviews_good_admiral = [] # список с положительными отзывами

for g8 in kinopoisk_url_list_good_admiral:
    try:
        rev_good8 = review_good_parsing_admiral(g8)
        all_reviews_good_admiral.append(rev_good8)
        sleep(5)
    except:
        print(g8) #try, except показывает, какая ссылка ломает парсер

# %%
df_good_admiral = pd.DataFrame(all_reviews_good_admiral)
df_good_admiral
# Out:
#                                                     0
# 0   \n\n\n\nСцены разворачиваются в 1915-1920 года...
# 1   \n\n\n\n«Адмирал» - очередная попытка российск...
# 2   \n\n\n\nЕдинственный фильм, который вызвал сле...
# 3   \n\n\n\nЭтот фильм тронул до глубины души, дав...
# 4   \n\n\n\nПосле просмотра этого фильма я, можно ...
# 5   \n\n\n\nИ вечный бой! Покой нам только снится\...
# 6   \n\n\n\nЭто замечательная картина, я думаю, бл...
# 7   \n\n\n\nК своему стыду фильм посмотрела только...
# 8   \n\n\n\nПосмотрела фильм по совету друзей, до ...
# 9   \n\n\n\nПосмотрел этот фильм с пребольшим удов...
# 10  \n\n\n\nЯ в восторге! Фильм стоит посмотреть д...
# 11  \n\n\n\nВ первую очередь хочу сказать, что мне...
# 12  \n\n\n\nОткровенно говоря, первое, что попало ...
# 13  \n\n\n\nГлавное отличие западного кинематограф...
# 14  \n\n\n\nТолько что из кинозала и уже пишу свой...
# 15  \n\n\n\nНе будучи ни в коей мере специалистом ...
# 16  \n\n\n\nВ последние годы, пусть и не очень час...
# 17  \n\n\n\nФильм приятно удивил. После 'Гитлер ка...
# 18  \n\n\n\nПризнаюсь, ждала выход АДМИРАЛА в нете...
# 19  \n\n\n\nСходил сегодня и посмотрел! Действител...

# %%
df_good_admiral.to_csv('Parsing_Admiral_good_fin.txt', sep='\t', index=False)

# %% [markdown]
# # Груз 200

# %% [markdown]
# ## Bad reviews (100) (выгружены)

# %%
page_link9 = 'https://www.kinopoisk.ru/film/259251/reviews/'
response9 = requests.get(page_link9, headers={'User-Agent': UserAgent().chrome})
url9 = 'https://www.kinopoisk.ru/film/259251/reviews/' 

r9 = requests.get(url9) # загружаем страницу по ссылке
print(r9.status_code)

if r9.status_code == 200:
    soup9 = BeautifulSoup(r9.text, features="html.parser")
    #print(soup9.prettify())
else:
    print("ERROR")
# Out:
# 200

# %%
kinopoisk_url_list_bad_cargo = []


for page_b9 in range(1, 11):
    url_page_bad9 = f'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/{page_b9}/'
    kinopoisk_url_list_bad_cargo.append(url_page_bad9)
print(kinopoisk_url_list_bad_cargo)
# Out:
# ['https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/9/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/bad/perpage/10/page/10/']

# %%
url_bad9 = kinopoisk_url_list_bad_cargo[0]

def review_bad_parsing_cargo(url_bad9):
    page_bad9 = requests.get(url_bad9)
    soup_bad9 = BeautifulSoup(page_bad9.text, features = 'html.parser')
    review_content_bad9 = soup_bad9.find_all('tbody')
    review_bad9 = [bad9.text for bad9 in review_content_bad9]
    final_review_bad9 = ' '.join(review_bad9)
    return final_review_bad9
#print(review_bad_parsing_cargo(url_bad9))

# %%
from time import sleep

all_reviews_bad_cargo = [] # список с отрицательными отзывами

for b9 in kinopoisk_url_list_bad_cargo:
    try:
        rev_bad9 = review_bad_parsing_cargo(b9)
        all_reviews_bad_cargo.append(rev_bad9)
        sleep(5)
    except:
        print(b9) #try, except показывает, какая ссылка ломает парсер

# %%
df_bad_cargo = pd.DataFrame(all_reviews_bad_cargo)
df_bad_cargo
# Out:
#                                                    0
# 0  \n\n\n\nЯ долго игнорировал существование твор...
# 1  \n\n\n\nНаконец-то решилась посмотреть этот фи...
# 2  \n\n\n\nЯ давно хотел посмотреть этот фильм, т...
# 3  \n\n\n\nКак и многих остальных для меня остаёт...
# 4  \n\n\n\nВот уже второй день не могу отделать о...
# 5  \n\n\n\nДля насильников, маньяков и извращенце...
# 6  \n\n\n\nПочему тов. Балабанов не снял крутого ...
# 7  \n\n\n\nНенавижу этот фильм! Так случилось, чт...
# 8  \n\n\n\nСмотрел фильм давно, предположительно ...
# 9  \n\n\n\nВчера посмотрел 'Груз 200'. Никогда ос...

# %%
df_bad_cargo.to_csv('Parsing_Cargo_bad_fin.txt', sep='\t', index=False)

# %% [markdown]
# ## Good reviews (160) (выгружены)

# %%
kinopoisk_url_list_good_cargo = []


for page_g9 in range(1, 17):
    url_page_good9 = f'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/{page_g9}/'
    kinopoisk_url_list_good_cargo.append(url_page_good9)
print(kinopoisk_url_list_good_cargo)
# Out:
# ['https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/1/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/2/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/3/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/4/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/5/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/6/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/7/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/8/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/9/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/10/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/11/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/12/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/13/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/14/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/15/', 'https://www.kinopoisk.ru/film/259251/reviews/ord/date/status/good/perpage/10/page/16/']

# %%
url_good9 = kinopoisk_url_list_good_cargo[0]

def review_good_parsing_cargo(url_good9):
    page_good9 = requests.get(url_good9)
    soup_good9 = BeautifulSoup(page_good9.text, features = 'html.parser')
    review_content_good9 = soup_good9.find_all('tbody')
    review_good9 = [good9.text for good9 in review_content_good9]
    final_review_good9 = ' '.join(review_good9)
    return final_review_good9
#print(review_good_parsing_cargo(url_good9))

# %%
from time import sleep

all_reviews_good_cargo = [] # список с положительными отзывами

for g9 in kinopoisk_url_list_good_cargo:
    try:
        rev_good9 = review_good_parsing_cargo(g9)
        all_reviews_good_cargo.append(rev_good9)
        sleep(5)
    except:
        print(g9) #try, except показывает, какая ссылка ломает парсер

# %%
df_good_cargo = pd.DataFrame(all_reviews_good_cargo)
df_good_cargo
# Out:
#                                                     0
# 0   \n\n\n\nМного чего было сказано за прошедшие с...
# 1   \n\n\n\nПравда, порой, в передачах-рассказах п...
# 2   \n\n\n\n'Многое увиденное здесь будет зависеть...
# 3   \n\n\n\nСкандальный фильм Алексея Октябринович...
# 4   \n\n\n\nСразу скажу. Фильм не просто великолеп...
# 5   \n\n\n\nДа всё было в СССР, и не только развра...
# 6   \n\n\n\nФильм долго не собиралась смотреть - п...
# 7   \n\n\n\nПосмотрев картину 'Груз 200' небезызве...
# 8   \n\n\n\nВсе говорили об этом фильме что он до ...
# 9   \n\n\n\nОчень сильный фильм.\n\r\nВсе же корот...
# 10  \n\n\n\nПеред просмотром прочитала множество о...
# 11  \n\n\n\nДля того, чтобы оценить к чему может п...
# 12  \n\n\n\nФильм мне понравился. Просто я это поч...
# 13  \n\n\n\nФильм шикарен! Во-первых он поучителен...
# 14  \n\n\n\nОчередной фильм Балабанова. Очень похо...
# 15  \n\n\n\nНачинается, в общем-то, как и все филь...

# %%
df_good_cargo.to_csv('Parsing_Cargo_good_fin.txt', sep='\t', index=False)
